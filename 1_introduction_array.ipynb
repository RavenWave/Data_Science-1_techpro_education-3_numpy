# %% [markdown]
# # **1. DERS: Introduction, array()**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *1) Data Science LifeCycle*

# %% [markdown]
# Makine Öğrenmesi Süreçleri:
#
# - Problemin Analizi
# - Veri Toplama
# - Veri Ön İşleme
# - EDA (Keşifsel Veri Analizi)
# - Model Oluşturma
# - Model Değerlendirme
# - Model Optimizasyonu
# - Model Dağıtımı
# - Model Güncelleme ve Bakım

# %% [markdown]
# Çöp Data'dan Çöp Sonuç doğar:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Data Science LifeCycle:
#
# - Data Collection
# - Data Cleaning
# - Data Exploration & Analysis (EDA)
# - Data Modelling
# - Data Validation
# - Deployment & Optimization

# %% [markdown]
# ## *2) Numpy Introduction*

# %% [markdown]
# Çok boyutlu diziler ve matrislerle çalışabiliriz.
#
# Matematiksel işlemler yapabiliriz.
#
# Numpy'ın temellerini array'ler oluşturur.
#
# bir numpy array, homojen yapıdadır (integer ise, hepsi integer. str ise hepsi str olmak zorunda)
#
# numpy hızlıdır: numpy c programlama diline göre yazılmıştır. bizim python olarak yazdığımız kodları, numpy c diline çevirip öyle işler ve o yüzden de çok daha hızlıdır (50 kat falan daha hızldıır normal python kodlarına göre)
#
# Numpy vektörel operasyonları destekler :
#
# Normalde aşağıdaki kodu list'ler ile yapsaydık, 6 elemanlı yeni bir liste elde etmiş olurduk
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## *3) Install & Import*

# %%
import numpy as np

# %% [markdown]
# ## *4) Scalar-Vector-Matrix-Tensor*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Scalar --> 0D [Tek bir değere sahip basit bir elemandır]
# - Vector --> 1D [sıralı eleman listesidir]
# - Matrix --> 2D [satırlar ve sütunlar vardır]
# - Tensor --> 3D [yükseklik, genişlik ve derinlik vardır]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#    ![image.png](attachment:image.png)

# %% [markdown]
# ## *5) Numpy Arrays - Notebook*
